# %%
import pandas as pd
import numpy as np
from IPython.display import display # Allows the use of display() for DataFrames
import time
import pickle #To save the objects 
import pprint
from lxml import html
import requests
from sklearn.model_selection import train_test_split
import warnings
warnings.filterwarnings('ignore')
from urllib.request import urlopen
from bs4 import BeautifulSoup
from IPython.display import HTML
import re
import urllib
import os
import matplotlib.pyplot as plt
import seaborn as sns

# %%
training_values = pd.read_csv('training_data.csv')
training_labels = pd.read_csv('training_labels.csv')

training_values.index = list(training_values['id'])
training_labels.index = list(training_labels['id'])
training_values.drop(["id"],axis=1,inplace=True)
training_labels.drop(["id"],axis=1,inplace=True)

training_data=training_values.join(training_labels,
                     how='inner',lsuffix='_values', 
                     rsuffix='labels')

print(training_data.shape)

df = training_data

avg_lat_long_by_ward_df = df[df['longitude'] != 0]. \
groupby(['ward'])['latitude','longitude'].mean().reset_index()
avg_lat_long_by_ward_df.columns=['ward','avg_latitude','avg_longitude']

avg_lat_long_by_lga_df = df[df['longitude'] != 0]. \
groupby(['lga'])['latitude','longitude'].mean().reset_index()
avg_lat_long_by_lga_df.columns=['lga','avg_latitude','avg_longitude']

avg_lat_long_by_region_df = df[df['longitude'] != 0]. \
groupby(['region'])['latitude','longitude'].mean().reset_index()

avg_lat_long_by_region_df.columns=['region','avg_latitude','avg_longitude']


print(avg_lat_long_by_ward_df.head())
print("\n\n")
print(avg_lat_long_by_lga_df.head())
print("\n\n")
print(avg_lat_long_by_region_df.head())


avg_lat_ward_dict = dict(zip(list(avg_lat_long_by_ward_df['ward']),list(avg_lat_long_by_ward_df['avg_latitude'])))
avg_long_ward_dict = dict(zip(list(avg_lat_long_by_ward_df['ward']),list(avg_lat_long_by_ward_df['avg_longitude'])))

avg_lat_lga_dict = dict(zip(list(avg_lat_long_by_lga_df['lga']),list(avg_lat_long_by_ward_df['avg_latitude'])))
avg_long_lga_dict = dict(zip(list(avg_lat_long_by_lga_df['lga']),list(avg_lat_long_by_ward_df['avg_longitude'])))

avg_lat_region_dict = dict(zip(list(avg_lat_long_by_region_df['region']),\
                               list(avg_lat_long_by_region_df['avg_latitude'])))

avg_long_region_dict = dict(zip(list(avg_lat_long_by_region_df['region']),\
                                list(avg_lat_long_by_region_df['avg_longitude'])))


latitude = []
longitude = []
for (i, j, k, l, m) in zip(list(df['latitude']),list(df['longitude']), \
                        list(df['ward']),list(df['lga']),list(df['region'])):
    if np.round(j) == 0 or np.round(j) == 0:
        try:
            latitude.append(avg_lat_ward_dict[k])
            longitude.append(avg_long_ward_dict[k])
        except:
            try:
                latitude.append(avg_lat_lga_dict[l])
                longitude.append(avg_long_lga_dict[l])
                continue
            except:
                try:
                    latitude.append(avg_lat_region_dict[m])
                    longitude.append(avg_long_region_dict[m])
                    continue
                except:   
                    print("Lat/Long NOT found at region level also. Terminating..")
    else:
        latitude.append(i)
        longitude.append(j)        

df["longitude_new"] = longitude        
df["latitude_new"] = latitude
# Out:
# (59400, 40)
#            ward  avg_latitude  avg_longitude
# 0       Aghondi     -5.755120      34.693194
# 1        Akheri     -3.362429      36.777714
# 2         Arash     -2.306235      35.516823
# 3          Arri     -4.226145      35.591610
# 4  Arusha Chini     -3.489923      37.352659
#
#
#
#             lga  avg_latitude  avg_longitude
# 0  Arusha Rural     -3.360196      36.700034
# 1  Arusha Urban     -3.391063      36.685110
# 2        Babati     -4.152541      35.668813
# 3      Bagamoyo     -6.461343      38.605186
# 4          Bahi     -6.075374      35.527319
#
#
#
#           region  avg_latitude  avg_longitude
# 0         Arusha     -3.246455      36.552713
# 1  Dar es Salaam     -6.909677      39.215799
# 2         Dodoma     -5.928734      36.044171
# 3         Iringa     -8.907700      34.895989
# 4         Kagera     -1.961466      31.233262

# %%
df[df["longitude"] == 0].tail(20)
# Out:
#        amount_tsh date_recorded        funder  gps_height     installer  \
# 13982         0.0    2013-01-21          Dwsp           0           DWE
# 10091         0.0    2011-07-19         Rwssp           0           DWE
# 48985         0.0    2012-10-24         Rwssp           0           DWE
# 63207         0.0    2012-10-26           Lwi           0           LWI
# 59410         0.0    2013-02-10          Dwsp           0           DWE
# 10595         0.0    2011-08-20         Tasaf           0         TASAF
# 22459         0.0    2013-02-27         Dwssp           0           DWE
# 62840         0.0    2013-01-19          Dwsp           0           DWE
# 35751         0.0    2013-02-04          Dwsp           0           DWE
# 34064         0.0    2011-08-18        Hesawa           0           DWE
# 26831         0.0    2011-08-25        Hesawa           0        Hesawa
# 28019         0.0    2011-07-19          Wsdp           0           DWE
# 5454          0.0    2012-11-04        Hesawa           0           DWE
# 52986         0.0    2013-01-22  World Vision           0  World Vision
# 62731         0.0    2012-10-26       Holland           0       HOLLAND
# 62177         0.0    2011-07-18          Dwsp           0           DWE
# 3631          0.0    2013-01-22          Dwsp           0           DWE
# 60843         0.0    2011-07-19         Rwssp           0           DWE
# 748           0.0    2013-01-22  World Vision           0  World Vision
# 49651         0.0    2012-10-29         Rwssp           0           DWE
#
#        longitude      latitude                    wpt_name  num_private  \
# 13982        0.0 -2.000000e-08                   Akinamama            0
# 10091        0.0 -2.000000e-08                      Upendo            0
# 48985        0.0 -2.000000e-08             Ujirani Mwema B            0
# 63207        0.0 -2.000000e-08                     Msituni            0
# 59410        0.0 -2.000000e-08                   Iloganota            0
# 10595        0.0 -2.000000e-08                     Bombani            0
# 22459        0.0 -2.000000e-08                 Imalamakoye            0
# 62840        0.0 -2.000000e-08                      Kisesa            0
# 35751        0.0 -2.000000e-08                    Muungano            0
# 34064        0.0 -2.000000e-08                     Shuleni            0
# 26831        0.0 -2.000000e-08                     Bombani            0
# 28019        0.0 -2.000000e-08                      Maweni            0
# 5454         0.0 -2.000000e-08                     Kwadeus            0
# 52986        0.0 -2.000000e-08  Shule Ya Msingi Mwakilangi            0
# 62731        0.0 -2.000000e-08                       Amani            0
# 62177        0.0 -2.000000e-08                      Wazazo            0
# 3631         0.0 -2.000000e-08                     Mtakuja            0
# 60843        0.0 -2.000000e-08                   Maendeleo            0
# 748          0.0 -2.000000e-08                    Mwazwilo            0
# 49651        0.0 -2.000000e-08                  Nguvu Kazi            0
#
#                  basin     ...           quantity quantity_group  \
# 13982    Lake Victoria     ...       insufficient   insufficient
# 10091    Lake Victoria     ...             enough         enough
# 48985    Lake Victoria     ...             enough         enough
# 63207    Lake Victoria     ...             enough         enough
# 59410    Lake Victoria     ...             enough         enough
# 10595  Lake Tanganyika     ...       insufficient   insufficient
# 22459    Lake Victoria     ...             enough         enough
# 62840    Lake Victoria     ...             enough         enough
# 35751    Lake Victoria     ...       insufficient   insufficient
# 34064  Lake Tanganyika     ...       insufficient   insufficient
# 26831    Lake Victoria     ...             enough         enough
# 28019    Lake Victoria     ...             enough         enough
# 5454     Lake Victoria     ...           seasonal       seasonal
# 52986    Lake Victoria     ...             enough         enough
# 62731    Lake Victoria     ...             enough         enough
# 62177    Lake Victoria     ...             enough         enough
# 3631     Lake Victoria     ...             enough         enough
# 60843    Lake Victoria     ...             enough         enough
# 748      Lake Victoria     ...             enough         enough
# 49651    Lake Victoria     ...             enough         enough
#
#              source   source_type source_class waterpoint_type  \
# 13982  shallow well  shallow well  groundwater       hand pump
# 10091  shallow well  shallow well  groundwater       hand pump
# 48985  shallow well  shallow well  groundwater       hand pump
# 63207  shallow well  shallow well  groundwater       hand pump
# 59410  shallow well  shallow well  groundwater       hand pump
# 10595   machine dbh      borehole  groundwater       hand pump
# 22459  shallow well  shallow well  groundwater       hand pump
# 62840  shallow well  shallow well  groundwater       hand pump
# 35751  shallow well  shallow well  groundwater       hand pump
# 34064  shallow well  shallow well  groundwater       hand pump
# 26831  shallow well  shallow well  groundwater       hand pump
# 28019  shallow well  shallow well  groundwater       hand pump
# 5454   shallow well  shallow well  groundwater       hand pump
# 52986  shallow well  shallow well  groundwater       hand pump
# 62731  shallow well  shallow well  groundwater           other
# 62177  shallow well  shallow well  groundwater       hand pump
# 3631   shallow well  shallow well  groundwater       hand pump
# 60843  shallow well  shallow well  groundwater       hand pump
# 748    shallow well  shallow well  groundwater       hand pump
# 49651  shallow well  shallow well  groundwater       hand pump
#
#        waterpoint_type_group             status_group longitude_new  \
# 13982              hand pump  functional needs repair     35.655813
# 10091              hand pump               functional     35.655813
# 48985              hand pump  functional needs repair     35.655813
# 63207              hand pump               functional     33.612516
# 59410              hand pump               functional     35.655813
# 10595              hand pump               functional     33.091564
# 22459              hand pump               functional     35.655813
# 62840              hand pump  functional needs repair     35.655813
# 35751              hand pump  functional needs repair     35.655813
# 34064              hand pump               functional     33.091564
# 26831              hand pump               functional     33.091564
# 28019              hand pump               functional     35.655813
# 5454               hand pump  functional needs repair     36.907890
# 52986              hand pump               functional     35.655813
# 62731                  other           non functional     33.612516
# 62177              hand pump  functional needs repair     34.298803
# 3631               hand pump               functional     35.655813
# 60843              hand pump  functional needs repair     35.655813
# 748                hand pump               functional     35.655813
# 49651              hand pump               functional     35.655813
#
#       latitude_new
# 13982    -5.642266
# 10091    -5.642266
# 48985    -5.642266
# 63207    -2.713541
# 59410    -5.642266
# 10595    -2.620502
# 22459    -5.642266
# 62840    -5.642266
# 35751    -5.642266
# 34064    -2.620502
# 26831    -2.620502
# 28019    -5.642266
# 5454     -7.808402
# 52986    -5.642266
# 62731    -2.713541
# 62177    -2.960822
# 3631     -5.642266
# 60843    -5.642266
# 748      -5.642266
# 49651    -5.642266
#
# [20 rows x 42 columns]

# %%
#Save file
df.to_csv("training_data_lat_long_handled.csv",index=False)

# %%
plt.figure(figsize=(16,10))
plt.title("Functional vs non-functional")
#Plot functional vs non-functional
plt.plot(df[df['status_group']=='functional']['longitude_new'],
        df[df['status_group']=='functional']['latitude_new'],color='g',linestyle='none',marker='.',alpha=0.8)

plt.plot(df[df['status_group']=='non functional']['longitude_new'],
        df[df['status_group']=='non functional']['latitude_new'],color='r',linestyle='none',marker='.',alpha=0.2)

#plt.plot(df[df['status_group']=='functional needs repair']['longitude_new'],
#        df[df['status_group']=='functional needs repair']['latitude_new'],color='y',linestyle='none',marker='.',alpha=0.8)
#plt.ylim(-2.5,-2.4)
#plt.xlim(30.5,30.75)
#plt.ylim(-12,-11)
#plt.xlim(35,36)

plt.show()

# %%
plt.figure(figsize=(16,10))
plt.title("Functional vs needs repair")
#Plot functional vs needs repair
plt.plot(df[df['status_group']=='functional']['longitude_new'],
        df[df['status_group']=='functional']['latitude_new'],color='g',linestyle='none',marker='.',alpha=0.8)

#plt.plot(df[df['status_group']=='non functional']['longitude_new'],
#        df[df['status_group']=='non functional']['latitude_new'],color='r',linestyle='none',marker='.',alpha=0.2)

plt.plot(df[df['status_group']=='functional needs repair']['longitude_new'],
        df[df['status_group']=='functional needs repair']['latitude_new'],color='y',linestyle='none',marker='.',alpha=0.8)
#plt.ylim(-2.5,-2.4)
#plt.xlim(30.5,30.75)
#plt.ylim(-12,-11)
#plt.xlim(35,36)

plt.show()

# %%
plt.figure(figsize=(16,10))
plt.title("Non-functional vs needs repair")
#Plot functional vs non-functional
#plt.plot(df[df['status_group']=='functional']['longitude_new'],
#        df[df['status_group']=='functional']['latitude_new'],color='g',linestyle='none',marker='.',alpha=0.8)

plt.plot(df[df['status_group']=='non functional']['longitude_new'],
        df[df['status_group']=='non functional']['latitude_new'],color='r',linestyle='none',marker='.',alpha=0.2)

plt.plot(df[df['status_group']=='functional needs repair']['longitude_new'],
        df[df['status_group']=='functional needs repair']['latitude_new'],color='y',linestyle='none',marker='.',alpha=0.8)
#plt.ylim(-2.5,-2.4)
#plt.xlim(30.5,30.75)
#plt.ylim(-12,-11)
#plt.xlim(35,36)

plt.show()

# %%
plt.figure(figsize=(16,10))
plt.title("Functional vs non-functional vs needs repair")
#Plot functional vs non-functional
plt.plot(df[df['status_group']=='functional']['longitude_new'],
        df[df['status_group']=='functional']['latitude_new'],color='g',linestyle='none',marker='.',alpha=0.8)

plt.plot(df[df['status_group']=='non functional']['longitude_new'],
        df[df['status_group']=='non functional']['latitude_new'],color='r',linestyle='none',marker='.',alpha=0.2)

plt.plot(df[df['status_group']=='functional needs repair']['longitude_new'],
        df[df['status_group']=='functional needs repair']['latitude_new'],color='y',linestyle='none',marker='.',alpha=0.8)
#plt.ylim(-2.5,-2.4)
#plt.xlim(30.5,30.75)
#plt.ylim(-12,-11)
#plt.xlim(35,36)

plt.show()
